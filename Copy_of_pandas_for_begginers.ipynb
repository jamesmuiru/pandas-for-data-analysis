# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # LOAD DATA

# %%
data=pd.read_csv('/content/drive/MyDrive/pandas and geopandas/Complete-Pandas-Course-main/Data/sales.csv',index_col='State')

# %% [markdown]
# # Getting the first 10 rows of our data

# %%
data.head(10)
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
# 5  California            99.0           Lemon  582.0  Major Market   291.0
# 6  California            25.0            Mint   90.0  Major Market    26.0
# 7  California            43.0      Darjeeling  276.0  Major Market   120.0
# 8  California            32.0       Earl Grey  187.0  Major Market    79.0
# 9  California           142.0       Columbian  687.0  Major Market   364.0
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# ...

# %% [markdown]
# Getting the last 10 rows of our data

# %%
data.tail(10)
# Out:
#           State  Total Expenses     Product  Sales   Market Size  Profit  \
# 4231  Wisconsin            25.0       Lemon  123.0  Small Market    64.0
# 4232  Wisconsin            40.0  Darjeeling  137.0  Small Market    41.0
# 4233  Wisconsin            38.0  Darjeeling  110.0  Small Market    27.0
# 4234  Wisconsin            35.0  Darjeeling   99.0  Small Market    24.0
# 4235  Wisconsin            33.0  Darjeeling   90.0  Small Market    21.0
# 4236  Wisconsin            34.0  Darjeeling   90.0  Small Market    20.0
# 4237  Wisconsin            36.0  Darjeeling  113.0  Small Market    31.0
# 4238  Wisconsin            86.0   Earl Grey  150.0  Small Market     1.0
# 4239  Wisconsin            79.0   Earl Grey  131.0  Small Market    -3.0
# 4240  Wisconsin            87.0   Earl Grey  165.0  Small Market     4.0
#
#        Market  Marketing Product Type  Inventory     Type
# 4231  Central         13   Herbal Tea      772.0    Decaf
# ...

# %% [markdown]
# # To see the number of  rows and columns of our data

# %%
data.shape
# Out:
# (4241, 11)

# %% [markdown]
# PANDAS DATAFRAMES AND SERIES
# *pandas dataframe is an object and since an object has attributes the our object Dataframe has attribute shape.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #To know the datatype in our Dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4241 entries, 0 to 4240
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           4241 non-null   object
#  1   Total Expenses  4238 non-null   float64
#  2   Product         4241 non-null   object
#  3   Sales           4239 non-null   float64
#  4   Market Size     4241 non-null   object
#  5   Profit          4235 non-null   float64
#  6   Market          4241 non-null   object
#  7   Marketing       4241 non-null   int64
#  8   Product Type    4241 non-null   object
#  9   Inventory       4240 non-null   float64
#  10  Type            4241 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 364.6+ KB

# %% [markdown]
# # To get statistical information regarding our data we use describe function/method(describe())

# %%
data.describe()
# Out:
#        Total Expenses        Sales       Profit    Marketing    Inventory
# count     4238.000000  4239.000000  4235.000000  4241.000000  4240.000000
# mean        53.989146   192.567351    60.840614    31.124499   747.971226
# std         32.295812   150.563621   101.301672    26.983618   660.498475
# min         10.000000    17.000000  -638.000000     0.000000 -3534.000000
# 25%         33.000000   100.000000    17.000000    13.000000   431.500000
# 50%         46.000000   138.000000    40.000000    22.000000   619.000000
# 75%         65.000000   230.000000    92.000000    39.000000   901.000000
# max        190.000000   912.000000   778.000000   156.000000  8252.000000

# %% [markdown]
# # converting a python list and dictionary into a dataframe

# %%
insects=['Ants','Cricket','Beee']

# %%
type(insects)
# Out:
# list

# %%
data_insects=pd.DataFrame(insects,columns=['insects'])
data_insects
# Out:
#    insects
# 0     Ants
# 1  Cricket
# 2     Beee

# %% [markdown]
# # Converting dictionaries into a Dataframe

# %%
animals={'Mammals':['Cow','Sheep','Lion'],'Reptiles':['Crocodile','Lizard','Snake'],'insects':['Ant','Cricket','Bee']}

# %%
type(animals)
# Out:
# dict

# %%
data_animals=pd.DataFrame(animals)
data_animals
# Out:
#   Mammals   Reptiles  insects
# 0     Cow  Crocodile      Ant
# 1   Sheep     Lizard  Cricket
# 2    Lion      Snake      Bee

# %%
data_animals['Mammals']
# Out:
# 0      Cow
# 1    Sheep
# 2     Lion
# Name: Mammals, dtype: object

# %%
# another way
data_animals.Reptiles
# Out:
# 0    Crocodile
# 1       Lizard
# 2        Snake
# Name: Reptiles, dtype: object

# %%
type(data_animals.Reptiles)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Note a single column of data is called  series
# ** a dataframe is then a container of a group of multiple series.so if each column is a series then a group of series is called a DataFrame.

# %% [markdown]
# #### How to access a row

# %%
data_animals.iloc[0]
# Out:
# Mammals           Cow
# Reptiles    Crocodile
# insects           Ant
# Name: 0, dtype: object

# %%
type(data_animals.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# :Then both row and columns of data are called Series

# %% [markdown]
# Getting the first and second row of data in pandas

# %%
data_animals.iloc[[0,1]]
# Out:
#   Mammals   Reptiles  insects
# 0     Cow  Crocodile      Ant
# 1   Sheep     Lizard  Cricket

# %% [markdown]
# ## Now lets work with our datasets

# %% [markdown]
# indexes in pandas

# %%
# indexes in pandas
data.head()
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
#
#            Market  Marketing Product Type  Inventory     Type
# State
# California   West         40       Coffee     2947.0  Regular
# California   West         24          Tea      659.0  Regular
# California   West        109     Espresso      788.0  Regular
# California   West         81     Espresso     1744.0    Decaf
# California   West         26   Herbal Tea      809.0    Decaf

# %%
# iloc attribute refers to integer location
data.iloc[4]
# Out:
# State               California
# Total Expenses            37.0
# Product              Chamomile
# Sales                    247.0
# Market Size       Major Market
# Profit                   148.0
# Market                    West
# Marketing                   26
# Product Type        Herbal Tea
# Inventory                809.0
# Type                     Decaf
# Name: 4, dtype: object

# %%
data.loc['California']
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# California            31.0            Mint  132.0  Major Market    43.0
# California            36.0      Darjeeling  238.0  Major Market   142.0
# California            40.0      Darjeeling  274.0  Major Market   166.0
# California            33.0       Earl Grey  198.0  Major Market    84.0
# California            83.0     Caffe Latte  451.0  Major Market   191.0
#
#            Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
data.loc['Colorado']
# Out:
#           Total Expenses    Product  Sales   Market Size  Profit   Market  \
# State
# Colorado            39.0   Amaretto  243.0  Major Market   105.0  Central
# Colorado            36.0   Amaretto  227.0  Major Market   134.0  Central
# Colorado            45.0   Amaretto  322.0  Major Market   199.0  Central
# Colorado            39.0  Columbian  190.0  Major Market    68.0  Central
# Colorado            39.0  Columbian  202.0  Major Market   101.0  Central
# ...                  ...        ...    ...           ...     ...      ...
# Colorado            34.0  Earl Grey   91.0  Major Market    16.0  Central
# Colorado            40.0  Earl Grey  145.0  Major Market    50.0  Central
# Colorado            41.0  Earl Grey  144.0  Major Market    47.0  Central
# Colorado            37.0  Earl Grey  126.0  Major Market    40.0  Central
# Colorado            37.0  Earl Grey  124.0  Major Market    39.0  Central
#
#           Marketing Product Type  Inventory     Type
# State
# ...

# %%
new_data=data.head()
new_data
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
#
#            Market  Marketing Product Type  Inventory     Type
# State
# California   West         40       Coffee     2947.0  Regular
# California   West         24          Tea      659.0  Regular
# California   West        109     Espresso      788.0  Regular
# California   West         81     Espresso     1744.0    Decaf
# California   West         26   Herbal Tea      809.0    Decaf

# %%
indexes=['One','Two','Three','Four','Five']
new_data.set_index([indexes],inplace=True)
new_data
# Out:
#        Total Expenses         Product  Sales   Market Size  Profit Market  \
# One              63.0        Amaretto  109.0  Major Market  -131.0   West
# Two              55.0       Green Tea  201.0  Major Market    88.0   West
# Three           143.0     Caffe Mocha  289.0  Major Market    25.0   West
# Four            113.0  Decaf Espresso  576.0  Major Market   216.0   West
# Five             37.0       Chamomile  247.0  Major Market   148.0   West
#
#        Marketing Product Type  Inventory     Type
# One           40       Coffee     2947.0  Regular
# Two           24          Tea      659.0  Regular
# Three        109     Espresso      788.0  Regular
# Four          81     Espresso     1744.0    Decaf
# Five          26   Herbal Tea      809.0    Decaf

# %%
new_data.loc['Two']
# Out:
# Total Expenses            55.0
# Product              Green Tea
# Sales                    201.0
# Market Size       Major Market
# Profit                    88.0
# Market                    West
# Marketing                   24
# Product Type               Tea
# Inventory                659.0
# Type                   Regular
# Name: Two, dtype: object

# %%
type(new_data.loc['Two'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Filtering rows and columns of data using pandas

# %%
data
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California            63.0        Amaretto  109.0  Major Market  -131.0
# California            55.0       Green Tea  201.0  Major Market    88.0
# California           143.0     Caffe Mocha  289.0  Major Market    25.0
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            37.0       Chamomile  247.0  Major Market   148.0
# ...                    ...             ...    ...           ...     ...
# Wisconsin             34.0      Darjeeling   90.0  Small Market    20.0
# Wisconsin             36.0      Darjeeling  113.0  Small Market    31.0
# Wisconsin             86.0       Earl Grey  150.0  Small Market     1.0
# Wisconsin             79.0       Earl Grey  131.0  Small Market    -3.0
# Wisconsin             87.0       Earl Grey  165.0  Small Market     4.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %% [markdown]
# using conditions

# %%
highest_sales=(data['Sales']>300)

# %%
highest_sales
# Out:
# State
# California    False
# California    False
# California    False
# California     True
# California    False
#               ...
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Name: Sales, Length: 4241, dtype: bool

# %%
data.loc[highest_sales]
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            99.0           Lemon  582.0  Major Market   291.0
# California           142.0       Columbian  687.0  Major Market   364.0
# California           166.0       Columbian  902.0  Major Market   508.0
# California           139.0       Columbian  664.0  Major Market   349.0
# ...                    ...             ...    ...           ...     ...
# Washington            71.0       Chamomile  329.0  Small Market   171.0
# Washington            73.0       Chamomile  334.0  Small Market   171.0
# Washington            75.0       Chamomile  347.0  Small Market   179.0
# Wisconsin            149.0       Columbian  317.0  Small Market    35.0
# Wisconsin            139.0       Columbian  314.0  Small Market    48.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
data.loc[highest_sales,['Product','Profit','Sales']]
# Out:
#                    Product  Profit  Sales
# State
# California  Decaf Espresso   216.0  576.0
# California           Lemon   291.0  582.0
# California       Columbian   364.0  687.0
# California       Columbian   508.0  902.0
# California       Columbian   349.0  664.0
# ...                    ...     ...    ...
# Washington       Chamomile   171.0  329.0
# Washington       Chamomile   171.0  334.0
# Washington       Chamomile   179.0  347.0
# Wisconsin        Columbian    35.0  317.0
# Wisconsin        Columbian    48.0  314.0
#
# [669 rows x 3 columns]

# %%
data['Product'].unique()
# Out:
# array(['Amaretto', 'Green Tea', 'Caffe Mocha', 'Decaf Espresso',
#        'Chamomile', 'Lemon', 'Mint', 'Darjeeling', 'Earl Grey',
#        'Columbian', 'Caffe Latte', 'Decaf Irish Cream',
#        'Regular Espresso'], dtype=object)

# %%
product=['Green Tea','Lemon','Mint']

# %%
filt=data['Product'].isin(product)

# %%
data.loc[filt]
# Out:
#             Total Expenses    Product  Sales   Market Size  Profit   Market  \
# State
# California            55.0  Green Tea  201.0  Major Market    88.0     West
# California            99.0      Lemon  582.0  Major Market   291.0     West
# California            25.0       Mint   90.0  Major Market    26.0     West
# California            54.0  Green Tea  168.0  Major Market    47.0     West
# California            88.0      Lemon  467.0  Major Market   165.0     West
# ...                    ...        ...    ...           ...     ...      ...
# Wisconsin             25.0      Lemon  143.0  Small Market    80.0  Central
# Wisconsin             20.0      Lemon   83.0  Small Market    40.0  Central
# Wisconsin             21.0      Lemon   91.0  Small Market    45.0  Central
# Wisconsin             27.0      Lemon  144.0  Small Market    58.0  Central
# Wisconsin             25.0      Lemon  123.0  Small Market    64.0  Central
#
# ...

# %% [markdown]
# ## updating rows and columns
#
# ```
# # This is formatted as code
# ```

# %%
data=pd.read_csv('/content/drive/MyDrive/pandas and geopandas/Complete-Pandas-Course-main/Data/sales.csv')

# %%
data
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
data.columns
# Out:
# Index(['State', 'Total Expenses', 'Product', 'Sales', 'Market Size', 'Profit',
#        'Market', 'Marketing', 'Product Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
data.Product Type
# Out:
#   File "<ipython-input-64-3222cd6945a4>", line 1
#     data.Product Type
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# replace method replace()

# %%
data.columns=data.columns.str.replace(' ','_')

# %%
data.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
#
#   Market  Marketing Product_Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf

# %%
data.Product_Type
# Out:
# 0           Coffee
# 1              Tea
# 2         Espresso
# 3         Espresso
# 4       Herbal Tea
#            ...
# 4236           Tea
# 4237           Tea
# 4238           Tea
# 4239           Tea
# 4240           Tea
# Name: Product_Type, Length: 4241, dtype: object

# %%
#renaming columns/modifying columns
data.rename(columns={'Marketing':'Trade'},inplace=True)

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %% [markdown]
# ## modifying the value of rows

# %%
data.loc[2,'Total_Expenses']=500

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           500.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
data.at[2,'Total_Expenses']=700

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %% [markdown]
# ## Add/Remove Rows And columns

# %%
# adding a new column
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
new_column=data['Total_Expenses']+data['Sales']

# %%
new_column
# Out:
# 0       172.0
# 1       256.0
# 2       989.0
# 3       689.0
# 4       284.0
#         ...
# 4236    124.0
# 4237    149.0
# 4238    236.0
# 4239    210.0
# 4240    252.0
# Length: 4241, dtype: float64

# %%
## adding a new column
data['New_column']=new_column

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
## removing a column(Product and market size)
data.drop(columns=['Product','Market_Size'],inplace=True)

# %%
data
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 0     California            63.0  109.0  -131.0     West     40       Coffee
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_column
# ...

# %% [markdown]
# using index parameter to drop rows of data

# %%
data.drop(index=0)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# 5     California            99.0  582.0   291.0     West     77   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_column
# ...

# %% [markdown]
# ## sorting data in pandas
#
#
# 1.   in ascending and descending order
# 2.   sorting data by multiple columns

# %%
data
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 0     California            63.0  109.0  -131.0     West     40       Coffee
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_column
# ...

# %%
data.sort_values(by='Sales')
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 1914      Nevada           126.0   17.0  -354.0     West     93          Tea
# 1923      Nevada           124.0   18.0  -524.0     West    100          Tea
# 1917      Nevada           133.0   18.0  -380.0     West    100          Tea
# 2036      Nevada           132.0   19.0  -552.0     West     93          Tea
# 2034      Nevada           147.0   19.0  -430.0     West    114          Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 131   California           178.0  910.0   368.0     West    127       Coffee
# 2644    New York           178.0  912.0   370.0     East    127       Coffee
# 157   California           178.0  912.0   370.0     West    127       Coffee
# 502     Colorado            54.0    NaN    80.0  Central     23     Espresso
# 508     Colorado            71.0    NaN    99.0  Central     47   Herbal Tea
#
#       Inventory     Type  New_column
# ...

# %%
# also by multiple columns.we input our column names to the by parameter
data.sort_values(by=['Sales','Trade'],ascending=False)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 157   California           178.0  912.0   370.0     West    127       Coffee
# 2644    New York           178.0  912.0   370.0     East    127       Coffee
# 131   California           178.0  910.0   368.0     West    127       Coffee
# 2645    New York           178.0  910.0   368.0     East    127       Coffee
# 132   California           166.0  904.0   511.0     West    127       Coffee
# ...          ...             ...    ...     ...      ...    ...          ...
# 1917      Nevada           133.0   18.0  -380.0     West    100          Tea
# 1923      Nevada           124.0   18.0  -524.0     West    100          Tea
# 1914      Nevada           126.0   17.0  -354.0     West     93          Tea
# 508     Colorado            71.0    NaN    99.0  Central     47   Herbal Tea
# 502     Colorado            54.0    NaN    80.0  Central     23     Espresso
#
#       Inventory     Type  New_column
# ...

# %%
data.sort_index(ascending=False)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 1     California            55.0  201.0    88.0     West     24          Tea
# 0     California            63.0  109.0  -131.0     West     40       Coffee
#
#       Inventory     Type  New_column
# ...

# %%
data['Market'].sort_values()
# Out:
# 4240    Central
# 1224    Central
# 1223    Central
# 1222    Central
# 1221    Central
#          ...
# 2142       West
# 2141       West
# 2140       West
# 2150       West
# 2120       West
# Name: Market, Length: 4241, dtype: object

# %% [markdown]
# ## clean and save the data

# %%
data.isnull().sum()
# Out:
# State             0
# Total_Expenses    3
# Sales             2
# Profit            6
# Market            0
# Trade             0
# Product_Type      0
# Inventory         1
# Type              0
# New_column        5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# State             0
# Total_Expenses    0
# Sales             0
# Profit            0
# Market            0
# Trade             0
# Product_Type      0
# Inventory         0
# Type              0
# New_column        0
# dtype: int64

# %%
data.to_csv('/content/drive/MyDrive/pandas and geopandas/New_sales.csv')
